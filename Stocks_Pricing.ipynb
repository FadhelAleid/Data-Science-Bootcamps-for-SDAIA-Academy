# %% [markdown]
# <a href="https://colab.research.google.com/github/FadhelAleid/Data-Science-Bootcamps-for-SDAIA-Academy/blob/main/Stocks_Pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The scope of this exercise is to look to the financial and trade data that could impact the valuation of stocks in Saudi Market.
# THe used data has been collected from yahoo finance which covred the following:
#
# *   200 Companies
# *   Last 4 years data
# *   Balancehseet
# *   Cashflow data
# *   Day trade data

# %% [markdown]
# ###Importing the Libraries and connect Colab to google drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from google.colab import drive

#Mount to the drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Importing the data

# %%
trade_raw_df=pd.read_csv('/content/gdrive/My Drive/SDAIA Course/Copy of day.csv')
bs_raw_df=pd.read_csv('/content/gdrive/My Drive/SDAIA Course/Copy of bs.csv')
cf_raw_df=pd.read_csv('/content/gdrive/My Drive/SDAIA Course/Copy of cf.csv')

# %% [markdown]
# ### Clean day trade data

# %%
#to be Converted it to function
temp = pd.DataFrame(trade_raw_df.groupby('ticker')[['ticker']].size().reset_index().rename(columns ={0 :'count'}))
ticker_1000 = temp[temp['count'] >= 1000].ticker.unique()
trade_df=trade_raw_df[trade_raw_df.ticker.isin(ticker_1000)]
# End of the function

#to be Converted it to function
temp = pd.DataFrame(bs_raw_df.groupby('ticker')[['ticker']].size().reset_index().rename(columns ={0 :'count'}))
ticker_4 = temp[temp['count'] == 4].ticker.unique()
bs_df=bs_raw_df[bs_raw_df.ticker.isin(ticker_4)]
# End of the function

#to be Converted it to function
temp = pd.DataFrame(cf_raw_df.groupby('ticker')[['ticker']].size().reset_index().rename(columns ={0 :'count'}))
ticker_4 = temp[temp['count'] == 4].ticker.unique()
cf_df=cf_raw_df[cf_raw_df.ticker.isin(ticker_4)]
# End of the function


#checking the data
trade_df.info()
trade_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172475 entries, 0 to 188597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    172475 non-null  int64
#  1   Date          172475 non-null  object
#  2   Open          172475 non-null  float64
#  3   High          172475 non-null  float64
#  4   Low           172475 non-null  float64
#  5   Close         172475 non-null  float64
#  6   Volume        172475 non-null  float64
#  7   Dividends     172475 non-null  float64
#  8   Stock Splits  172475 non-null  float64
#  9   ticker        172475 non-null  int64
#  10  Adj Close     0 non-null       float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 15.8+ MB
#    Unnamed: 0        Date       Open  ...  Stock Splits  ticker  Adj Close
# 0           0  2018-01-01  28.611736  ...           0.0    2030        NaN
# 1           1  2018-01-02  28.565737  ...           0.0    2030        NaN
# 2           2  2018-01-03  28.427737  ...           0.0    2030        NaN
# 3           3  2018-01-04  28.427738  ...           0.0    2030        NaN
# 4           4  2018-01-07  28.519739  ...           0.0    2030        NaN
#
# [5 rows x 11 columns]

# %%
#lower case all columns
trade_df.columns= trade_df.columns.str.lower().str.replace(' ', '_')

#Convert to the acurate format
trade_df["ticker"]= trade_df["ticker"].apply(str)
trade_df['date']=pd.to_datetime(trade_df['date'], errors='coerce')

#Drop un wanted columns
trade_df=trade_df.drop(["unnamed:_0","dividends","adj_close"],axis=1)

#Creat new id to merge with other data
trade_df["id"]=trade_df['date'].dt.year.astype(str)+"-"+trade_df["ticker"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#re-checking the data
trade_df.info()
trade_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172475 entries, 0 to 188597
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          172475 non-null  datetime64[ns]
#  1   open          172475 non-null  float64
#  2   high          172475 non-null  float64
#  3   low           172475 non-null  float64
#  4   close         172475 non-null  float64
#  5   volume        172475 non-null  float64
#  6   stock_splits  172475 non-null  float64
#  7   ticker        172475 non-null  object
#  8   id            172475 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 13.2+ MB
#         date       open       high  ...  stock_splits  ticker         id
# 0 2018-01-01  28.611736  28.611736  ...           0.0    2030  2018-2030
# 1 2018-01-02  28.565737  28.611738  ...           0.0    2030  2018-2030
# 2 2018-01-03  28.427737  28.473738  ...           0.0    2030  2018-2030
# 3 2018-01-04  28.427738  28.565736  ...           0.0    2030  2018-2030
# 4 2018-01-07  28.519739  28.887735  ...           0.0    2030  2018-2030
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Cleaning Balance sheet data

# %%
#checking the data
bs_df.info()
bs_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 804
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        760 non-null    int64
#  1   Unnamed: 1                        760 non-null    object
#  2   Total Liab                        759 non-null    float64
#  3   Total Stockholder Equity          759 non-null    float64
#  4   Other Current Liab                750 non-null    float64
#  5   Total Assets                      759 non-null    float64
#  6   Common Stock                      759 non-null    float64
#  7   Other Current Assets              724 non-null    float64
#  8   Retained Earnings                 739 non-null    float64
#  9   Other Liab                        742 non-null    float64
#  10  Treasury Stock                    525 non-null    float64
#  11  Cash                              759 non-null    float64
#  12  Total Current Liabilities         758 non-null    float64
#  13  Other Stockholder Equity          524 non-null    float64
#  14  Property Plant Equipment          758 non-null    float64
#  15  Total Current Assets              759 non-null    float64
#  16  Long Term Investments             527 non-null    float64
#  17  Net Tangible Assets               759 non-null    float64
#  18  Net Receivables                   748 non-null    float64
#  19  ticker                            760 non-null    int64
#  20  date                              760 non-null    object
#  21  Intangible Assets                 524 non-null    float64
#  22  Capital Surplus                   70 non-null     float64
#  23  Minority Interest                 251 non-null    float64
#  24  Good Will                         204 non-null    float64
#  25  Other Assets                      500 non-null    float64
#  26  Deferred Long Term Asset Charges  81 non-null     float64
#  27  Short Long Term Debt              425 non-null    float64
#  28  Short Term Investments            175 non-null    float64
#  29  Long Term Debt                    443 non-null    float64
#  30  Inventory                         557 non-null    float64
#  31  Accounts Payable                  723 non-null    float64
#  32  Deferred Long Term Liab           93 non-null     float64
#  33  index                             0 non-null      object
# dtypes: float64(29), int64(2), object(3)
# memory usage: 207.8+ KB
#    Unnamed: 0  Unnamed: 1  ...  Deferred Long Term Liab  index
# 0           0  2020-12-31  ...                      NaN    NaN
# 1           1  2019-12-31  ...                      NaN    NaN
# 2           2  2018-12-31  ...                      NaN    NaN
# 3           3  2017-12-31  ...                      NaN    NaN
# 4           4  2020-12-31  ...                      NaN    NaN
#
# [5 rows x 34 columns]

# %%
#lower case all columns
bs_df.columns= bs_df.columns.str.lower().str.replace(' ', '_')

#Convert to the acurate format
bs_df["ticker"]= bs_df["ticker"].apply(str)
bs_df['date']=pd.to_datetime(bs_df['date'], errors='coerce')

#Remove rows with no data
bs_df= bs_df[bs_df['index'].isnull()]

#Creat new id to merge with other data
bs_df["id"]=(bs_df['date'].dt.year-1).astype(str)+"-"+bs_df["ticker"]


#Drop un wanted columns
bs_df=bs_df.drop(["unnamed:_0","unnamed:_1","index","treasury_stock","date"],axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#re-checking the data
bs_df.info()
bs_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 804
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   total_liab                        759 non-null    float64
#  1   total_stockholder_equity          759 non-null    float64
#  2   other_current_liab                750 non-null    float64
#  3   total_assets                      759 non-null    float64
#  4   common_stock                      759 non-null    float64
#  5   other_current_assets              724 non-null    float64
#  6   retained_earnings                 739 non-null    float64
#  7   other_liab                        742 non-null    float64
#  8   cash                              759 non-null    float64
#  9   total_current_liabilities         758 non-null    float64
#  10  other_stockholder_equity          524 non-null    float64
#  11  property_plant_equipment          758 non-null    float64
#  12  total_current_assets              759 non-null    float64
#  13  long_term_investments             527 non-null    float64
#  14  net_tangible_assets               759 non-null    float64
#  15  net_receivables                   748 non-null    float64
#  16  ticker                            760 non-null    object
#  17  intangible_assets                 524 non-null    float64
#  18  capital_surplus                   70 non-null     float64
#  19  minority_interest                 251 non-null    float64
#  20  good_will                         204 non-null    float64
#  21  other_assets                      500 non-null    float64
#  22  deferred_long_term_asset_charges  81 non-null     float64
#  23  short_long_term_debt              425 non-null    float64
#  24  short_term_investments            175 non-null    float64
#  25  long_term_debt                    443 non-null    float64
#  26  inventory                         557 non-null    float64
#  27  accounts_payable                  723 non-null    float64
#  28  deferred_long_term_liab           93 non-null     float64
#  29  id                                760 non-null    object
# dtypes: float64(28), object(2)
# memory usage: 184.1+ KB
#      total_liab  total_stockholder_equity  ...  deferred_long_term_liab         id
# 0  1.027033e+07              5.083243e+08  ...                      NaN  2019-2030
# 1  1.105980e+07              4.539620e+08  ...                      NaN  2018-2030
# 2  1.049018e+07              4.305261e+08  ...                      NaN  2017-2030
# 3  1.349543e+07              3.672804e+08  ...                      NaN  2016-2030
# 4  8.131670e+11              9.908480e+11  ...                      NaN  2019-2222
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Clean Cash flow data

# %%
#checking the data
cf_df.info()
cf_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 806
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 756 non-null    int64
#  1   Unnamed: 1                                 756 non-null    object
#  2   Investments                                513 non-null    float64
#  3   Change To Liabilities                      756 non-null    float64
#  4   Total Cashflows From Investing Activities  755 non-null    float64
#  5   Total Cash From Financing Activities       716 non-null    float64
#  6   Change To Operating Activities             681 non-null    float64
#  7   Net Income                                 756 non-null    float64
#  8   Change In Cash                             756 non-null    float64
#  9   Total Cash From Operating Activities       756 non-null    float64
#  10  Depreciation                               756 non-null    float64
#  11  Dividends Paid                             455 non-null    float64
#  12  Change To Netincome                        756 non-null    float64
#  13  Capital Expenditures                       727 non-null    float64
#  14  Change To Account Receivables              690 non-null    float64
#  15  ticker                                     756 non-null    int64
#  16  date                                       756 non-null    object
#  17  Net Borrowings                             676 non-null    float64
#  18  Other Cashflows From Investing Activities  384 non-null    float64
#  19  Change To Inventory                        510 non-null    float64
#  20  Other Cashflows From Financing Activities  427 non-null    float64
#  21  Repurchase Of Stock                        56 non-null     float64
#  22  Effect Of Exchange Rate                    121 non-null    float64
#  23  Issuance Of Stock                          87 non-null     float64
#  24  index                                      0 non-null      object
# dtypes: float64(20), int64(2), object(3)
# memory usage: 153.6+ KB
#    Unnamed: 0  Unnamed: 1  ...  Issuance Of Stock  index
# 0           0  2020-12-31  ...                NaN    NaN
# 1           1  2019-12-31  ...                NaN    NaN
# 2           2  2018-12-31  ...                NaN    NaN
# 3           3  2017-12-31  ...                NaN    NaN
# 4           4  2020-12-31  ...                NaN    NaN
#
# [5 rows x 25 columns]

# %%
#lower case all columns
cf_df.columns= cf_df.columns.str.lower().str.replace(' ', '_')

#Convert to the acurate format
cf_df["ticker"]= cf_df["ticker"].apply(str)
cf_df['date']=pd.to_datetime(cf_df['date'], errors='coerce')

#Remove rows with no data
cf_df= cf_df[cf_df['index'].isnull()]

#Creat new id to merge with other data
cf_df["id"]=(cf_df['date'].dt.year-1).astype(str)+"-"+cf_df["ticker"]

#Drop un wanted columns
cf_df=cf_df.drop(["unnamed:_0","unnamed:_1","index","date"],axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#re-checking the data
cf_df.info()
cf_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 806
# Data columns (total 22 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   investments                                513 non-null    float64
#  1   change_to_liabilities                      756 non-null    float64
#  2   total_cashflows_from_investing_activities  755 non-null    float64
#  3   total_cash_from_financing_activities       716 non-null    float64
#  4   change_to_operating_activities             681 non-null    float64
#  5   net_income                                 756 non-null    float64
#  6   change_in_cash                             756 non-null    float64
#  7   total_cash_from_operating_activities       756 non-null    float64
#  8   depreciation                               756 non-null    float64
#  9   dividends_paid                             455 non-null    float64
#  10  change_to_netincome                        756 non-null    float64
#  11  capital_expenditures                       727 non-null    float64
#  12  change_to_account_receivables              690 non-null    float64
#  13  ticker                                     756 non-null    object
#  14  net_borrowings                             676 non-null    float64
#  15  other_cashflows_from_investing_activities  384 non-null    float64
#  16  change_to_inventory                        510 non-null    float64
#  17  other_cashflows_from_financing_activities  427 non-null    float64
#  18  repurchase_of_stock                        56 non-null     float64
#  19  effect_of_exchange_rate                    121 non-null    float64
#  20  issuance_of_stock                          87 non-null     float64
#  21  id                                         756 non-null    object
# dtypes: float64(20), object(2)
# memory usage: 135.8+ KB
#     investments  change_to_liabilities  ...  issuance_of_stock         id
# 0 -6.009969e+06           0.000000e+00  ...                NaN  2019-2030
# 1 -1.087824e+06           0.000000e+00  ...                NaN  2018-2030
# 2 -1.087824e+06           0.000000e+00  ...                NaN  2017-2030
# 3 -1.087824e+06           0.000000e+00  ...                NaN  2016-2030
# 4  4.853600e+10          -1.625000e+10  ...                NaN  2019-2222
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Merging the data

# %%
merged_df = pd.merge(trade_df, bs_df,how="left", on=["id"])
merged_df = pd.merge(merged_df, cf_df,how="left", on=["id"])

# %%
#re-checking the data
merged_df.info()
merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174555 entries, 0 to 174554
# Data columns (total 59 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   date                                       174555 non-null  datetime64[ns]
#  1   open                                       174555 non-null  float64
#  2   high                                       174555 non-null  float64
#  3   low                                        174555 non-null  float64
#  4   close                                      174555 non-null  float64
#  5   volume                                     174555 non-null  float64
#  6   stock_splits                               174555 non-null  float64
#  7   ticker_x                                   174555 non-null  object
#  8   id                                         174555 non-null  object
#  9   total_liab                                 86330 non-null   float64
#  10  total_stockholder_equity                   86330 non-null   float64
#  11  other_current_liab                         85809 non-null   float64
#  12  total_assets                               86330 non-null   float64
#  13  common_stock                               86330 non-null   float64
#  14  other_current_assets                       83469 non-null   float64
#  15  retained_earnings                          83990 non-null   float64
#  16  other_liab                                 84770 non-null   float64
#  17  cash                                       86330 non-null   float64
#  18  total_current_liabilities                  86330 non-null   float64
#  19  other_stockholder_equity                   63716 non-null   float64
#  20  property_plant_equipment                   86330 non-null   float64
#  21  total_current_assets                       86330 non-null   float64
#  22  long_term_investments                      61907 non-null   float64
#  23  net_tangible_assets                        86330 non-null   float64
#  24  net_receivables                            84509 non-null   float64
#  25  ticker_y                                   87110 non-null   object
#  26  intangible_assets                          62395 non-null   float64
#  27  capital_surplus                            7284 non-null    float64
#  28  minority_interest                          28580 non-null   float64
#  29  good_will                                  25213 non-null   float64
#  30  other_assets                               59811 non-null   float64
#  31  deferred_long_term_asset_charges           9884 non-null    float64
#  32  short_long_term_debt                       47323 non-null   float64
#  33  short_term_investments                     20552 non-null   float64
#  34  long_term_debt                             50444 non-null   float64
#  35  inventory                                  64993 non-null   float64
#  36  accounts_payable                           83990 non-null   float64
#  37  deferred_long_term_liab                    11956 non-null   float64
#  38  investments                                57993 non-null   float64
#  39  change_to_liabilities                      86590 non-null   float64
#  40  total_cashflows_from_investing_activities  86330 non-null   float64
#  41  total_cash_from_financing_activities       80866 non-null   float64
#  42  change_to_operating_activities             75923 non-null   float64
#  43  net_income                                 86590 non-null   float64
#  44  change_in_cash                             86590 non-null   float64
#  45  total_cash_from_operating_activities       86590 non-null   float64
#  46  depreciation                               86590 non-null   float64
#  47  dividends_paid                             45256 non-null   float64
#  48  change_to_netincome                        86590 non-null   float64
#  49  capital_expenditures                       83730 non-null   float64
#  50  change_to_account_receivables              78536 non-null   float64
#  51  ticker                                     86590 non-null   object
#  52  net_borrowings                             76703 non-null   float64
#  53  other_cashflows_from_investing_activities  41615 non-null   float64
#  54  change_to_inventory                        59270 non-null   float64
#  55  other_cashflows_from_financing_activities  41856 non-null   float64
#  56  repurchase_of_stock                        5465 non-null    float64
#  57  effect_of_exchange_rate                    14808 non-null   float64
#  58  issuance_of_stock                          6768 non-null    float64
# dtypes: datetime64[ns](1), float64(54), object(4)
# memory usage: 79.9+ MB
#         date       open  ...  effect_of_exchange_rate  issuance_of_stock
# 0 2018-01-01  28.611736  ...                      NaN                NaN
# 1 2018-01-02  28.565737  ...                      NaN                NaN
# 2 2018-01-03  28.427737  ...                      NaN                NaN
# 3 2018-01-04  28.427738  ...                      NaN                NaN
# 4 2018-01-07  28.519739  ...                      NaN                NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# #### Number of rows has been increased after the merge, I have to double check that I have unique id in the data sets

# %%
#Remove rows with no data
merged_df= merged_df[merged_df['total_assets'].notnull()]

#Drop un wanted columns
merged_df=merged_df.drop(["id","ticker_y"],axis=1)

#merged_df["company_value"]=merged_df["common_stock"]*merged_df["close"]

#fill na by zero
merged_df=merged_df.fillna(0)

# %%
#re-checking the data
merged_df.info()
merged_df.head()
merged_df.groupby("ticker_x").count()["date"].sort_values(ascending = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86330 entries, 0 to 174053
# Data columns (total 57 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   date                                       86330 non-null  datetime64[ns]
#  1   open                                       86330 non-null  float64
#  2   high                                       86330 non-null  float64
#  3   low                                        86330 non-null  float64
#  4   close                                      86330 non-null  float64
#  5   volume                                     86330 non-null  float64
#  6   stock_splits                               86330 non-null  float64
#  7   ticker_x                                   86330 non-null  object
#  8   total_liab                                 86330 non-null  float64
#  9   total_stockholder_equity                   86330 non-null  float64
#  10  other_current_liab                         86330 non-null  float64
#  11  total_assets                               86330 non-null  float64
#  12  common_stock                               86330 non-null  float64
#  13  other_current_assets                       86330 non-null  float64
#  14  retained_earnings                          86330 non-null  float64
#  15  other_liab                                 86330 non-null  float64
#  16  cash                                       86330 non-null  float64
#  17  total_current_liabilities                  86330 non-null  float64
#  18  other_stockholder_equity                   86330 non-null  float64
#  19  property_plant_equipment                   86330 non-null  float64
#  20  total_current_assets                       86330 non-null  float64
#  21  long_term_investments                      86330 non-null  float64
#  22  net_tangible_assets                        86330 non-null  float64
#  23  net_receivables                            86330 non-null  float64
#  24  intangible_assets                          86330 non-null  float64
#  25  capital_surplus                            86330 non-null  float64
#  26  minority_interest                          86330 non-null  float64
#  27  good_will                                  86330 non-null  float64
#  28  other_assets                               86330 non-null  float64
#  29  deferred_long_term_asset_charges           86330 non-null  float64
#  30  short_long_term_debt                       86330 non-null  float64
#  31  short_term_investments                     86330 non-null  float64
#  32  long_term_debt                             86330 non-null  float64
#  33  inventory                                  86330 non-null  float64
#  34  accounts_payable                           86330 non-null  float64
#  35  deferred_long_term_liab                    86330 non-null  float64
#  36  investments                                86330 non-null  float64
#  37  change_to_liabilities                      86330 non-null  float64
#  38  total_cashflows_from_investing_activities  86330 non-null  float64
#  39  total_cash_from_financing_activities       86330 non-null  float64
#  40  change_to_operating_activities             86330 non-null  float64
#  41  net_income                                 86330 non-null  float64
#  42  change_in_cash                             86330 non-null  float64
#  43  total_cash_from_operating_activities       86330 non-null  float64
#  44  depreciation                               86330 non-null  float64
#  45  dividends_paid                             86330 non-null  float64
#  46  change_to_netincome                        86330 non-null  float64
#  47  capital_expenditures                       86330 non-null  float64
#  48  change_to_account_receivables              86330 non-null  float64
#  49  ticker                                     86330 non-null  object
#  50  net_borrowings                             86330 non-null  float64
#  51  other_cashflows_from_investing_activities  86330 non-null  float64
#  52  change_to_inventory                        86330 non-null  float64
#  53  other_cashflows_from_financing_activities  86330 non-null  float64
#  54  repurchase_of_stock                        86330 non-null  float64
#  55  effect_of_exchange_rate                    86330 non-null  float64
#  56  issuance_of_stock                          86330 non-null  float64
# dtypes: datetime64[ns](1), float64(54), object(2)
# memory usage: 38.2+ MB
# ticker_x
# 4100    1820
# 7040     772
# 1304     770
# 4240     770
# 2270     770
#         ...
# 4250     520
# 4260     520
# 4270     520
# 1010     520
# 8290     260
# Name: date, Length: 162, dtype: int64

# %%
merged_df.describe()
# Out:
#                open          high  ...  effect_of_exchange_rate  issuance_of_stock
# count  86330.000000  86330.000000  ...             8.633000e+04       8.633000e+04
# mean      28.038952     28.332329  ...            -3.581439e+06       8.109175e+07
# std       22.947340     23.181080  ...             4.336388e+07       5.466267e+08
# min        4.913211      4.913211  ...            -6.321220e+08       0.000000e+00
# 25%       13.507652     13.650785  ...             0.000000e+00       0.000000e+00
# 50%       20.031827     20.243153  ...             0.000000e+00       0.000000e+00
# 75%       32.450001     32.799999  ...             0.000000e+00       0.000000e+00
# max      185.771278    190.410732  ...             6.051151e+07       5.000000e+09
#
# [8 rows x 54 columns]

# %% [markdown]
# ###EDA

# %%
#Find the correlation between the features and the closing price
merged_df.corrwith(merged_df["close"], axis = 0).sort_values(ascending = False)
# Out:
# close                                        1.000000
# high                                         0.999832
# low                                          0.999816
# open                                         0.999678
# retained_earnings                            0.297476
# inventory                                    0.267254
# net_income                                   0.237041
# minority_interest                            0.231412
# deferred_long_term_asset_charges             0.214933
# cash                                         0.209063
# total_current_assets                         0.196509
# good_will                                    0.193932
# total_stockholder_equity                     0.191819
# other_current_liab                           0.191591
# net_tangible_assets                          0.182761
# net_receivables                              0.178513
# depreciation                                 0.174872
# deferred_long_term_liab                      0.169780
# change_to_inventory                          0.155227
# other_cashflows_from_investing_activities    0.144963
# change_to_netincome                          0.122250
# total_assets                                 0.116723
# short_term_investments                       0.104823
# total_cash_from_operating_activities         0.100399
# long_term_investments                        0.093254
# common_stock                                 0.082566
# other_current_assets                         0.075801
# total_liab                                   0.072482
# property_plant_equipment                     0.071520
# total_current_liabilities                    0.064956
# other_cashflows_from_financing_activities    0.062268
# other_liab                                   0.061302
# intangible_assets                            0.058954
# accounts_payable                             0.057124
# other_assets                                 0.048209
# capital_surplus                              0.039658
# change_to_account_receivables                0.037117
# long_term_debt                               0.030372
# issuance_of_stock                            0.014814
# stock_splits                                 0.007782
# short_long_term_debt                         0.001200
# change_in_cash                              -0.001415
# investments                                 -0.012208
# total_cash_from_financing_activities        -0.021429
# other_stockholder_equity                    -0.024442
# change_to_liabilities                       -0.032014
# volume                                      -0.058436
# net_borrowings                              -0.058515
# change_to_operating_activities              -0.061870
# effect_of_exchange_rate                     -0.070053
# repurchase_of_stock                         -0.086821
# total_cashflows_from_investing_activities   -0.146086
# capital_expenditures                        -0.172950
# dividends_paid                              -0.341635
# dtype: float64

# %% [markdown]
# ####Plotting the data

# %%
#Check the frequcncy of the data in the data sets
sns.histplot(data=trade_df, x="ticker")

# %%
bs_df.groupby("ticker").count()["id"].sort_values(ascending = False)
sns.histplot(data=bs_df, x="ticker")

# %%
cf_df.groupby("ticker").count()["id"].sort_values(ascending = False)
sns.histplot(data=bs_df, x="ticker")

# %%
for col in ["high","low","retained_earnings","inventory","dividends_paid"]:
  plt.figure()
  sns.scatterplot(data=merged_df, x="close", y=col ,hue="ticker_x",legend = False).set(yscale="log")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Data Pre-Processing

# %%
x=merged_df.drop(columns=["close","ticker","date","ticker_x","ticker"])
y= merged_df.close
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %% [markdown]
# ### Modeling

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df

sns.lineplot(data=df)

# %%
# Model Acuracy
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R Squared Error:', metrics.r2_score(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.13990040832761372
# Mean Squared Error: 0.06587081377386526
# R Squared Error: 0.9998756208931449
# Root Mean Squared Error: 0.2566531000667346

# %% [markdown]
# ### Removing day prices to check the impact

# %%
x=merged_df.drop(columns=["close","ticker","date","ticker_x","ticker","open","high","low"])
y= merged_df.close
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)


reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df

sns.lineplot(data=df)


# Model Acuracy
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R Squared Error:', metrics.r2_score(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 13.029924638126655
# Mean Squared Error: 344.00437366854607
# R Squared Error: 0.3504413517940904
# Root Mean Squared Error: 18.54735489681874

# %% [markdown]
# # Further work is needed to enhance the model as it is overfited if day trade data date is used, and the error is so high if it is dismissed.
